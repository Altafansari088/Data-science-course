# %% [markdown]
# Q1: The difference between a t-test and a z-test:
#
# A t-test is used when the sample size is small (typically less than 30) or when the population standard deviation is unknown. It is used to compare the means of two groups.
# A z-test is used when the sample size is large (typically greater than 30) and the population standard deviation is known. It is also used to compare the means of two groups.
# Example scenario for t-test: You want to compare the average test scores of two different groups of students (Group A and Group B) to determine if there is a significant difference in their performance.
#
# Example scenario for z-test: You want to compare the average heights of two different populations (Population A and Population B) to determine if there is a significant difference in their heights.
#
# Q2: One-tailed and two-tailed tests:
#
# In a one-tailed test, the alternative hypothesis is directional, meaning it specifies whether the parameter is expected to be greater than or less than the hypothesized value.
#
# In a two-tailed test, the alternative hypothesis is non-directional, meaning it specifies that the parameter is expected to be different (either greater or less) from the hypothesized value.
#
# Q3: Type 1 and Type 2 errors in hypothesis testing:
#
# Type 1 error (α error): It occurs when we reject the null hypothesis when it is actually true. This means we conclude that there is a significant effect or difference when there isn't one.
# Type 2 error (β error): It occurs when we fail to reject the null hypothesis when it is actually false. This means we fail to detect a significant effect or difference when there is one.
#
# Example scenario for Type 1 error: A medical test falsely indicates that a person has a disease when they are actually healthy.
# Example scenario for Type 2 error: A medical test fails to detect a disease in a person who actually has it.
#
# Q4: Bayes's theorem:
#
# Bayes's theorem is a mathematical formula used to calculate the probability of an event occurring given prior knowledge of the event's probability and new evidence.
# Example: Let's say you want to calculate the probability of a person having a certain disease given that they tested positive for it. You would need to know the prior probability of having the disease, the probability of testing positive given that the person has the disease, and the probability of testing positive given that the person does not have the disease.
#
# Q5: Confidence interval:
#
# A confidence interval is a range of values that is likely to contain the true population parameter with a certain level of confidence. It provides a measure of the uncertainty associated with estimating the population parameter based on a sample.
#
# To calculate a confidence interval, you need the sample mean, sample standard deviation (or standard error), sample size, and the desired level of confidence. The formula for calculating a confidence interval depends on the distribution of the data and the type of parameter being estimated (e.g., mean, proportion).
# Example: Let's say you want to estimate the average height of a population with a 95% confidence level. You would calculate the confidence interval using the sample mean, sample standard deviation, sample size, and the appropriate formula based on the distribution of the data.
#
# Q6: Use Bayes' Theorem to calculate the probability of an event occurring given prior knowledge of the event's probability and new evidence. Provide a sample problem and solution.
#
# Example problem:
# A factory produces two types of products, A and B. Product A has a defect rate of 5%, while product B has a defect rate of 10%. You randomly select a product from the factory and find that it is defective. What is the probability that the product is type A?
# Solution:
# Let's define the events:
#
# A: Selecting product A
#
# B: Selecting product B
#
# D: The product is defective
#
# We are given:
# P(A) = 0.5 (since there are equal numbers of product A and B)
#
# P(B) = 0.5 (since there are equal numbers of product A and B)
#
# P(D|A) = 0.05 (probability of a defective product given it is type A)
#
# P(D|B) = 0.10 (probability of a defective product given it is type B)
#
# Q7: Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5. Interpret the results.
# To calculate the confidence interval, we need the sample mean, sample standard deviation, sample size, and the desired level of confidence. Since the sample size is not provided, we'll assume a sample size of 30 for this example.
# Given:
# Sample mean (x̄) = 50
#
# Sample standard deviation (s) = 5
#
# Sample size (n) = 30
#
# Confidence level = 95%
#
# The formula to calculate the confidence interval for the population mean is:
# Confidence Interval = x̄ ± (z * (s / √n))
#
# We are 95% confident that the true population mean falls within the range of approximately 48.18 to 51.82. This means that if we were to repeat the sampling process multiple times and calculate the confidence interval each time, approximately 95% of the intervals would contain the true population mean.
#
# Q8: What is the margin of error in a confidence interval? How does sample size affect the margin of error? Provide an example of a scenario where a larger sample size would
# result in a smaller margin of error.
#
# The margin of error is the range of values around the sample estimate (e.g., sample mean or sample proportion) within which the true population parameter is likely to fall with a certain level of confidence. It represents the uncertainty associated with estimating the population parameter based on a sample.
# The margin of error is influenced by several factors, including the sample size. As the sample size increases, the margin of error decreases. This is because a larger sample size provides more information and reduces the variability in the sample estimate.
# Example scenario:
#
# Suppose you want to estimate the proportion of people in a city who support a particular political candidate. You take two different samples: Sample A with a size of 100 and Sample B with a size of 1000.
#
# In Sample A, you find that 60% of the respondents support the candidate, while in Sample B, you find that 65% of the respondents support the candidate.
#
# Since Sample B has a larger sample size, it will have a smaller margin of error compared to Sample A. This means that the estimate of the proportion in Sample B is likely to be more precise and closer to the true population proportion compared to Sample A.
#
# Q9: Calculate the z-score for a data point with a value of 75, a population mean of 70, and a population standard deviation of 5. Interpret the results.
# The z-score (also known as the standard score) measures the number of standard deviations a data point is away from the mean. It helps in understanding how unusual or typical a particular data point is within a distribution.
#
# The formula to calculate the z-score is:
#
# z = (x - μ) / σ
#
# Where:
#
# x = data point
#
# μ = population mean
#
# σ = population standard deviation
#
# Substituting the values:
#
# z = (75 - 70) / 5 = 1
# Interpretation:
#
# The data point with a value of 75 is 1 standard deviation above the population mean of 70. This means that the data point is relatively higher than the average value in the population.
#
# Q10: In a study of the effectiveness of a new weight loss drug, a sample of 50 participants lost an average of 6 pounds with a standard deviation of 2.5 pounds. Conduct a hypothesis test to determine if the drug is significantly effective at a 95% confidence level using a t-test.
#
# To conduct a hypothesis test, we need to state the null hypothesis (H0) and the alternative hypothesis (Ha). In this case:
#
# H0: The new weight loss drug has no significant effect (mean weight loss = 0)
#
# Ha: The new weight loss drug has a significant effect (mean weight loss ≠ 0)
#
# We will use a two-tailed t-test since the alternative hypothesis is non-directional.
# Given:
#
# Sample mean (x̄) = 6 pounds
#
# Sample standard deviation (s) = 2.5 pounds
#
# Sample size (n) = 50
#
# Confidence level = 95%
#
# The formula to calculate the t-statistic is:
#
# t = (x̄ - μ) / (s / √n)
#
# Where:
#
# x̄ = sample mean
#
# μ = hypothesized population mean (in this case, 0)
#
# s = sample standard deviation
#
# n = sample size
#
# Substituting the values:
#
# t = (6 - 0) / (2.5 / √50) ≈ 13.42
#
# To determine if the drug is significantly effective, we compare the calculated t-statistic with the critical t-value at the desired confidence level and degrees of freedom (n-1). Since the sample size is 50, the degrees of freedom will be 49.
#
# Using a t-table or statistical software, we find that the critical t-value for a two-tailed test at a 95% confidence level with 49 degrees of freedom is approximately ±2.009.
# Since the calculated t-statistic (13.42) is much larger than the critical t-value (2.009), we can reject the null hypothesis. This means that the new weight loss drug is significantly effective at a 95% confidence level.
#
# Q11: In a survey of 500 people, 65% reported being satisfied with their current job. Calculate the 95% confidence interval for the true proportion of people who are satisfied with their job.
#
# To calculate the confidence interval for a proportion, we need the sample proportion, sample size, and the desired level of confidence.
# Given:
#
# Sample proportion (p̂) = 0.65
#
# Sample size (n) = 500
#
# Confidence level = 95%
#
# The formula to calculate the confidence interval for a proportion is:
#
# Confidence Interval = p̂ ± (z * √((p̂ * (1 - p̂)) / n))
#
# Where:
#
# p̂ = sample proportion
#
# z = z-score corresponding to the desired confidence level (for a 95% confidence level, z = 1.96)
#
# n = sample size
#
# Substituting the values:
#
# Confidence Interval = 0.65 ± (1.96 * √((0.65 * (1 - 0.65)) / 500))
#
# Calculating the standard error (√((p̂ * (1 - p̂)) / n)):
#
# Standard Error = √((0.65 * (1 - 0.65)) / 500) ≈ 0.0202
#
# Confidence Interval = 0.65 ± (1.96 * 0.0202)
#
# Calculating the upper and lower bounds of the confidence interval:
#
# Lower bound = 0.65 - (1.96 * 0.0202) ≈ 0.609
#
# Upper bound = 0.65 + (1.96 * 0.0202) ≈ 0.691
#
# Interpretation:
#
# We are 95% confident that the true proportion of people who are satisfied with their job falls within the range of approximately 0.609 to 0.691. This means that if we were to repeat the survey multiple times and calculate the confidence interval each time, approximately 95% of the intervals would contain the true population proportion.
#
# Q12: A researcher is testing the effectiveness of two different teaching methods on student performance. Sample A has a mean score of 85 with a standard deviation of 6, while sample B has a mean score of 82 with a standard deviation of 5. Conduct a hypothesis test to determine if the two teaching methods have a significant difference in student performance using a t-test with a significance level of 0.01.
#
# To conduct a hypothesis test for comparing the means of two independent samples, we need to state the null hypothesis (H0) and the alternative hypothesis (Ha). In this case:
#
# H0: The two teaching methods have no significant difference in student performance (μA = μB)
#
# Ha: The two teaching methods have a significant difference in student performance (μA ≠ μB)
#
# We will use a two-tailed t-test since the alternative hypothesis is non-directional.
# Given:
#
# Sample A mean (x̄A) = 85
#
# Sample A standard deviation (sA) = 6
#
# Sample A size (nA) = ?
#
# Sample B mean (x̄B) = 82
#
# Sample B standard deviation (sB) = 5
#
# Sample B size (nB) = ?
#
# Significance level (α) = 0.01
#
# Since the sample sizes (nA and nB) are not provided, we cannot calculate the t-statistic directly. Please provide the sample sizes to proceed with the hypothesis test.
#
# Q13: A population has a mean of 60 and a standard deviation of 8. A sample of 50 observations has a mean of 65. Calculate the 90% confidence interval for the true population mean.
# To calculate the confidence interval for the population mean, we need the sample mean, sample size, population mean, population standard deviation, and the desired level of confidence.
#
# Q14: In a study of the effects of caffeine on reaction time, a sample of 30 participants had an average reaction time of 0.25 seconds with a standard deviation of 0.05
# seconds. Conduct a hypothesis test to determine if caffeine has a significant effect on reaction time at a 90% confidence level using a t-test
#
# To conduct a hypothesis test, we need to state the null hypothesis (H0) and the alternative hypothesis (Ha). In this case:
#
# H0: Caffeine has no significant effect on reaction time (μ = 0)
#
# Ha: Caffeine has a significant effect on reaction time (μ ≠ 0)
#
# We will use a two-tailed t-test since the alternative hypothesis is non-directional.
